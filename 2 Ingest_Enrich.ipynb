# %% [markdown]
# # Add weather data to the game results
# 1. Read the CSV file into a dataframe
# 2. Add columns for weather data and odds
# 3. Get latitude and longitude from stadium column
# 4. Use latitude and longitude to call NOAA API for weather on game date
# 5. Write out the enriched dataframe to a new csv file

# %% [markdown]
# ### Import necessary libraries

# %%
# Libraries for formatting in/out
import json
import csv
from datetime import datetime, timedelta

# Libraries to help with data manipulation
import pandas as pd
import matplotlib.pyplot as plt

# Import Meteostat library and dependencies
# !pip install meteostat
#from meteostat import Point, Daily
from meteostat import Point, Daily


# Supress Warnings Messages
import warnings
warnings.filterwarnings('ignore')
# Out:
# Collecting meteostat
#   Downloading meteostat-1.6.7-py3-none-any.whl (31 kB)
# Requirement already satisfied: pandas>=1.1 in /usr/local/lib/python3.10/dist-packages (from meteostat) (2.0.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from meteostat) (2023.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from meteostat) (1.25.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1->meteostat) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1->meteostat) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1->meteostat) (1.16.0)
# Installing collected packages: meteostat
# Successfully installed meteostat-1.6.7

# %% [markdown]
# Mount Google Drive and Load the CSV to a Dataframe

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_json('/content/drive/MyDrive/Colab Notebooks/IIT/ncaa_football/1 Make CSVs/csv_files/2013-2023-json.json')

# %%
# Add columns for weather
df['StadiumIDNumber'] = None
df['StadiumName'] = None
df['latitude'] = None
df['longitude'] = None
df['avg_temp'] = None
df['min_temp'] = None
df['max_temp'] = None
df['prcp'] = None
df['snow'] = None
df['wspd'] = None
df['hdir'] = None
df['pres'] = None
df['tsun'] = None

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9707 entries, 0 to 9706
# Data columns (total 61 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GameID                 9707 non-null   int64
#  1   Season                 9707 non-null   int64
#  2   SeasonType             9707 non-null   int64
#  3   Week                   9707 non-null   int64
#  4   Status                 9707 non-null   object
#  5   Day                    9707 non-null   object
#  6   DateTime               9032 non-null   datetime64[ns]
#  7   AwayTeam               9707 non-null   object
#  8   HomeTeam               9707 non-null   object
#  9   AwayTeamID             9707 non-null   int64
#  10  HomeTeamID             9707 non-null   int64
#  11  AwayTeamName           9707 non-null   object
#  12  HomeTeamName           9707 non-null   object
#  13  AwayTeamScore          8889 non-null   float64
#  14  HomeTeamScore          8889 non-null   float64
#  15  Period                 8163 non-null   object
#  16  TimeRemainingMinutes   7 non-null      float64
#  17  TimeRemainingSeconds   7 non-null      float64
#  18  PointSpread            6385 non-null   float64
#  19  OverUnder              6351 non-null   float64
#  20  AwayTeamMoneyLine      4894 non-null   float64
#  21  HomeTeamMoneyLine      4892 non-null   float64
#  22  Updated                9707 non-null   object
#  23  Created                9707 non-null   object
#  24  GlobalGameID           9707 non-null   int64
#  25  GlobalAwayTeamID       9707 non-null   int64
#  26  GlobalHomeTeamID       9707 non-null   int64
#  27  StadiumID              9682 non-null   float64
#  28  YardLine               1 non-null      float64
#  29  YardLineTerritory      9707 non-null   object
#  30  Down                   8 non-null      float64
#  31  Distance               8 non-null      float64
#  32  Possession             9707 non-null   object
#  33  IsClosed               9707 non-null   bool
#  34  GameEndDateTime        9025 non-null   object
#  35  Title                  92 non-null     object
#  36  HomeRotationNumber     3881 non-null   float64
#  37  AwayRotationNumber     3881 non-null   float64
#  38  Channel                4078 non-null   object
#  39  NeutralVenue           4769 non-null   float64
#  40  AwayPointSpreadPayout  2570 non-null   float64
#  41  HomePointSpreadPayout  2570 non-null   float64
#  42  OverPayout             2570 non-null   float64
#  43  UnderPayout            2570 non-null   float64
#  44  DateTimeUTC            9032 non-null   object
#  45  Attendance             2572 non-null   float64
#  46  Stadium                9682 non-null   object
#  47  Periods                9707 non-null   object
#  48  StadiumIDNumber        0 non-null      object
#  49  StadiumName            0 non-null      object
#  50  latitude               0 non-null      object
#  51  longitude              0 non-null      object
#  52  avg_temp               0 non-null      object
#  53  min_temp               0 non-null      object
#  54  max_temp               0 non-null      object
#  55  prcp                   0 non-null      object
#  56  snow                   0 non-null      object
#  57  wspd                   0 non-null      object
#  58  hdir                   0 non-null      object
#  59  pres                   0 non-null      object
#  60  tsun                   0 non-null      object
# dtypes: bool(1), datetime64[ns](1), float64(20), int64(9), object(30)
# memory usage: 4.5+ MB

# %%
df.describe()
# Out:
#              GameID       Season  SeasonType         Week  \
# count   9707.000000  9707.000000      9707.0  9707.000000
# mean    8303.223756  2018.185845         1.0     7.173483
# min       75.000000  2013.000000         1.0     1.000000
# 25%     6711.500000  2016.000000         1.0     3.000000
# 50%     9255.000000  2018.000000         1.0     7.000000
# 75%    11967.500000  2021.000000         1.0    11.000000
# max    14534.000000  2023.000000         1.0    16.000000
# std     4494.441638     3.114557         0.0     4.146278
#
#                             DateTime   AwayTeamID   HomeTeamID  AwayTeamScore  \
# count                           9032  9707.000000  9707.000000    8889.000000
# mean   2018-11-01 10:49:02.823294720   165.862676   159.121974      25.003262
# min              2013-08-29 18:00:00     1.000000     1.000000       0.000000
# 25%              2015-11-21 12:00:00    95.000000    94.000000      11.000000
# 50%              2018-10-13 15:30:00   177.000000   143.000000      21.000000
# 75%              2021-10-02 12:00:00   252.000000   251.000000      36.000000
# max              2023-12-09 15:00:00  1024.000000   921.000000     117.000000
# std                              NaN   101.136628    99.954689      19.371971
#
#        HomeTeamScore  TimeRemainingMinutes  ...  Down  Distance  \
# count    8889.000000                   7.0  ...   8.0       8.0
# mean       32.412420                   0.0  ...   0.0       0.0
# min         0.000000                   0.0  ...   0.0       0.0
# 25%        16.000000                   0.0  ...   0.0       0.0
# 50%        28.000000                   0.0  ...   0.0       0.0
# 75%        46.000000                   0.0  ...   0.0       0.0
# max       131.000000                   0.0  ...   0.0       0.0
# std        22.427205                   0.0  ...   0.0       0.0
#
#        HomeRotationNumber  AwayRotationNumber  NeutralVenue  \
# count         3881.000000         3881.000000   4769.000000
# mean         31017.929915        31016.920381      0.021388
# min             32.000000           32.000000      0.000000
# 25%            141.000000          141.000000      0.000000
# 50%            237.000000          236.000000      0.000000
# 75%            437.000000          436.000000      0.000000
# max         525517.000000       525515.000000      1.000000
# std         106125.671634       106125.592451      0.144690
#
#        AwayPointSpreadPayout  HomePointSpreadPayout   OverPayout  UnderPayout  \
# count            2570.000000            2570.000000  2570.000000  2570.000000
# mean             -114.126070            -114.128016  -114.441245  -114.374319
# min              -205.000000            -208.000000  -199.000000  -197.000000
# 25%              -153.000000            -153.000000  -153.000000  -153.000000
# 50%              -124.000000            -123.000000  -124.000000  -124.000000
# 75%               -71.000000             -71.000000   -71.000000   -71.000000
# max               142.000000             141.000000   -34.000000    56.000000
# std                49.204521              48.943334    48.014699    48.233569
#
#           Attendance
# count    2572.000000
# mean    39977.174572
# min         0.000000
# 25%     18253.500000
# 50%     33749.000000
# 75%     55847.250000
# max    111156.000000
# std     27045.944405
#
# [8 rows x 30 columns]

# %%
#test it
i=1

#unpack the stadium dictionary
dict_stadium = df['Stadium'][i]
df['StadiumIDNumber'][i] = dict_stadium["StadiumID"]
df['StadiumName'][i] = dict_stadium["Name"]
df['latitude'][i] = dict_stadium["GeoLat"]
df['longitude'][i] = dict_stadium["GeoLong"]

# %%
#build the API call
dflat = df['latitude'][i]
dflong = df['longitude'][i]

# %%
#override for testing
end = df['DateTime'][i]
start = end - timedelta(days=1)
thepoint = Point(dflat, dflong)
data = Daily(thepoint, start, end)

# %%
print(start)
# Out:
# 2013-08-29 22:00:00

# %%
print(end)
# Out:
# 2013-08-30 22:00:00

# %%
data = data.fetch()

# %%
# loop through dataframe and pull the latitude and longitude from the embedded stadium dictionary into new columns
for i in range(len(df)):
  if df['Stadium'][i] is not None:
    dict_stadium = df['Stadium'][i]
    df['StadiumIDNumber'][i] = dict_stadium["StadiumID"]
    df['StadiumName'][i] = dict_stadium["Name"]
    df['latitude'][i] = dict_stadium["GeoLat"]
    df['longitude'][i] = dict_stadium["GeoLong"]
    if df['DateTime'][i] is not None:
      dflat = df['latitude'][i]
      dflong = df['longitude'][i]
#     Build the Weather API Call
      end = df['DateTime'][i]
      start = end - timedelta(days=1)
      thepoint = Point(dflat, dflong)
      data = Daily(thepoint, start, end)
      data = data.fetch()
      df['avg_temp'][i] = data['tavg']
      df['min_temp'][i] = data['tmin']
      df['max_temp'][i] = data['tmax']
      df['prcp'][i] = data['prcp']
      df['snow'][i] = data['snow']
      df['wspd'][i] = data['wspd']
      df['hdir'][i] = data['wdir']
      df['pres'][i] = data['pres']
      df['tsun'][i] = data['tsun']
  if i % 100 == 0:        # Check if i is divisible by 100
    print(i), " rows processed"
#  if  20:
#    break
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'NoneType' object has no attribute 'deg2rad'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-2456e554baf7> in <cell line: 2>()
#      14       start = end - timedelta(days=1)
#      15       thepoint = Point(dflat, dflong)
# ---> 16       data = Daily(thepoint, start, end)
#      17       data = data.fetch()
#      18       df['avg_temp'][i] = data['tavg']
#
# /usr/local/lib/python3.10/dist-packages/meteostat/interface/daily.py in __init__(self, loc, start, end, model, flags)
#      96
#      97         # Initialize time series
# ---> 98         self._init_time_series(loc, start, end, model, flags)
#      99
#     100     def expected_rows(self) -> int:
#
# /usr/local/lib/python3.10/dist-packages/meteostat/interface/timeseries.py in _init_time_series(self, loc, start, end, model, flags)
#     154             self._stations = loc.index
#     155         elif isinstance(loc, Point):
# --> 156             stations = loc.get_stations("daily", start, end, model)
#     157             self._stations = stations.index
#     158         else:
#
# /usr/local/lib/python3.10/dist-packages/meteostat/interface/point.py in get_stations(self, freq, start, end, model)
#      75         # Get nearby weather stations
#      76         stations = Stations()
# ---> 77         stations = stations.nearby(self._lat, self._lon, self.radius)
#      78
#      79         # Guess altitude if not set
#
# /usr/local/lib/python3.10/dist-packages/meteostat/interface/stations.py in nearby(self, lat, lon, radius)
#     116
#     117         # Get distance for each station
# --> 118         temp._data["distance"] = get_distance(
#     119             lat, lon, temp._data["latitude"], temp._data["longitude"]
#     120         )
#
# /usr/local/lib/python3.10/dist-packages/meteostat/utilities/helpers.py in get_distance(lat1, lon1, lat2, lon2)
#      20
#      21     # Degress to radian
# ---> 22     lat1, lon1, lat2, lon2 = map(np.deg2rad, [lat1, lon1, lat2, lon2])
#      23
#      24     # Deltas
#
# TypeError: loop of ufunc does not support argument 0 of type NoneType which has no callable deg2rad method

# %%
# copying the data to another variable to avoid any changes to original data
dfcopy = df.copy()

# %%
# Write the df to a CSV file
dfcopy.to_csv("/content/drive/MyDrive/Colab Notebooks/IIT/ncaa_football/1 Make CSVs/csv_files/2013-2023-with-weather-new-csv.csv", index=False)

# %%
# Write the df to a CSV file
dfcopy.to_json("/content/drive/MyDrive/Colab Notebooks/IIT/ncaa_football/1 Make CSVs/csv_files/2013-2023-with-weather-new-json.csv", orient='split', index=False)

# %% [markdown]
# ***
